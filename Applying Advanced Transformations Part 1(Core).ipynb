# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df = pd.read_csv('data/superhero_powers - superhero_powers.csv')
df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
df_info = pd.read_csv('data/superhero_info - superhero_info.csv')
df_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
cat_cols = df_info
for col in cat_cols:
  display(df_info[col].value_counts())
# Out:
# Spider-Man|Marvel Comics       3
# Black Canary|DC Comics         2
# Nova|Marvel Comics             2
# Toxin|Marvel Comics            2
# Batman|DC Comics               2
#                               ..
# Fabian Cortez|Marvel Comics    1
# Exodus|Marvel Comics           1
# Evilhawk|Marvel Comics         1
# Evil Deadpool|Marvel Comics    1
# Zoom|DC Comics                 1
# Name: Hero|Publisher, Length: 457, dtype: int64
# Male       321
# Female     134
# Unknown      8
# Name: Gender, dtype: int64
# Human                156
# Unknown              145
# Mutant                51
# Human / Radiation     11
# Android                7
# Symbiote               7
# Alien                  6
# Demon                  6
# Cyborg                 6
# Kryptonian             5
# Atlantean              5
# Asgardian              5
# Inhuman                4
# New God                3
# Human-Kree             2
# Eternal                2
# Demi-God               2
# ...

# %%
df_info['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
## adding expand=True
df_info['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
df_info[['Hero','Publisher']] = df_info['Hero|Publisher'].str.split('|',expand=True)
df_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
# Make a list of all characters to replace
to_replace = ["{","}", "'", "'", "Height:", "Weight:","cm", "kg"]
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    df_info['Measurements'] = df_info['Measurements'].str.replace(char,'',regex=False)
    
df_info['Measurements'].head()
# Out:
# 0     203.0 ,  441.0
# 1      191.0 ,  65.0
# 2      185.0 ,  90.0
# 3     203.0 ,  441.0
# 4     193.0 ,  122.0
# Name: Measurements, dtype: object

# %%
df_info[['Height (cm)','Weight (kg)']] = df_info['Measurements'].str.split(',',expand=True)
df_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color      Measurements        Hero          Publisher  \
# 0    yellow    Unknown   203.0 ,  441.0       A-Bomb      Marvel Comics
# 1      blue       blue    191.0 ,  65.0   Abe Sapien  Dark Horse Comics
#
#   Height (cm) Weight (kg)
# 0      203.0       441.0
# 1      191.0        65.0

# %%
df_info = df_info.drop(columns=['Hero|Publisher', 'Measurements'])
df_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height (cm) Weight (kg)
# 0      Marvel Comics      203.0       441.0
# 1  Dark Horse Comics      191.0        65.0

# %%
df_info["Height (cm)"] = df_info[["Height (cm)"]].astype(float)

# %%
df_info["Height (cm)"].head()
# Out:
# 0    203.0
# 1    191.0
# 2    185.0
# 3    203.0
# 4    193.0
# Name: Height (cm), dtype: float64

# %%
df_info["Weight (kg)"] = df_info["Weight (kg)"].astype(float)
df_info["Weight (kg)"].head()
# Out:
# 0    441.0
# 1     65.0
# 2     90.0
# 3    441.0
# 4    122.0
# Name: Weight (kg), dtype: float64

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       463 non-null    object
#  1   Race         463 non-null    object
#  2   Alignment    463 non-null    object
#  3   Hair color   463 non-null    object
#  4   Eye color    463 non-null    object
#  5   Skin color   463 non-null    object
#  6   Hero         463 non-null    object
#  7   Publisher    463 non-null    object
#  8   Height (cm)  463 non-null    float64
#  9   Weight (kg)  463 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 36.3+ KB

# %%
## showing the lists are really strings
df.loc[0,'Powers']
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
## adding expand=True
# Create a new column where they were converted back to lists
df["powers_split"] = df['Powers'].str.split(',')
df["powers_split"].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
exploded = df.explode('powers_split')

# %%
cols_to_make = exploded['powers_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
  df[col] = df['Powers'].str.contains(col)
df.head()
# Out:
# C:\Users\caill\AppData\Local\Temp\ipykernel_27564\1587836609.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col] = df['Powers'].str.contains(col)
# C:\Users\caill\AppData\Local\Temp\ipykernel_27564\1587836609.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[col] = df['Powers'].str.contains(col)
# ...

# %%
df = df.drop(columns=["Powers"])
## save data
df.to_csv('advanced_ps_data_pt1.csv', index=False)

# %%
df.head()
# Out:
#     hero_names                                       powers_split  Agility  \
# 0      3-D Man    [Agility, Super Strength, Stamina, Super Speed]     True
# 1       A-Bomb  [Accelerated Healing, Durability, Longevity, S...    False
# 2   Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...     True
# 3     Abin Sur                               [Lantern Power Ring]    False
# 4  Abomination  [Accelerated Healing, Intelligence, Super Stre...    False
#
#    Super Strength  Stamina  Super Speed  Accelerated Healing  Durability  \
# 0            True     True         True                False       False
# 1            True     True        False                 True        True
# 2            True     True        False                 True        True
# 3           False    False        False                False       False
# 4            True     True         True                 True       False
#
#    Longevity  Camouflage  ...  Weather Control  Omnipresent  Omniscient  \
# ...

# %%
merged_df = pd.merge(df_info, df, left_on = "Hero", right_on="hero_names")
merged_df = merged_df.drop(columns=["hero_names"])
merged_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height (cm)  Weight (kg)  ...  \
# 0         A-Bomb      Marvel Comics        203.0        441.0  ...
# 1     Abe Sapien  Dark Horse Comics        191.0         65.0  ...
# 2       Abin Sur          DC Comics        185.0         90.0  ...
# 3    Abomination      Marvel Comics        203.0        441.0  ...
# 4  Absorbing Man      Marvel Comics        193.0        122.0  ...
#
#   Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# ...

# %%
# Compare the average weight of super powers who have Super Speed to those who do not.
speed_and_weight = merged_df.groupby('Super Speed')['Weight (kg)'].mean()

speed_and_weight.sort_values(ascending=False)
# Out:
# Super Speed
# True     129.404040
# False    101.773585
# Name: Weight (kg), dtype: float64

# %%
# What is the average height of heroes for each publisher?.
pub_height = merged_df.groupby('Publisher')['Height (cm)'].mean()

pub_height.sort_values(ascending=False)
# Out:
# Publisher
# Image Comics         211.000000
# Marvel Comics        191.546128
# DC Comics            181.923913
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Dark Horse Comics    176.909091
# Shueisha             171.500000
# George Lucas         159.600000
# Name: Height (cm), dtype: float64
