# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df = pd.read_csv('data/superhero_powers - superhero_powers.csv')
df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
df_info = pd.read_csv('data/superhero_info - superhero_info.csv')
df_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
info = df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
cat_cols = df
for col in cat_cols:
  display(df[col].value_counts())
# Out:
# 3-D Man            1
# Namora             1
# Naruto Uzumaki     1
# Nathan Petrelli    1
# Nebula             1
#                   ..
# Evilhawk           1
# Exodus             1
# Fabian Cortez      1
# Falcon             1
# Zoom               1
# Name: hero_names, Length: 667, dtype: int64
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# ...

# %%
df_info['Hero|Publisher'].head(2)
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# Name: Hero|Publisher, dtype: object

# %%
## adding expand=True
df_info['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
df_info[['Hero','Publisher']] = df_info['Hero|Publisher'].str.split('|',expand=True)
df_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
# Make a list of all characters to replace
to_replace = ["{","}", "'", "'", "Height:", "Weight:","cm", "kg"]
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    df_info['Measurements'] = df_info['Measurements'].str.replace(char,'',regex=False)
    
df_info['Measurements'].head()
# Out:
# 0     203.0 ,  441.0
# 1      191.0 ,  65.0
# 2      185.0 ,  90.0
# 3     203.0 ,  441.0
# 4     193.0 ,  122.0
# Name: Measurements, dtype: object

# %%
df_info[['Height (cm)','Weight (kg)']] = df_info['Measurements'].str.split(',',expand=True)
df_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color      Measurements        Hero          Publisher  \
# 0    yellow    Unknown   203.0 ,  441.0       A-Bomb      Marvel Comics
# 1      blue       blue    191.0 ,  65.0   Abe Sapien  Dark Horse Comics
#
#   Height (cm) Weight (kg)
# 0      203.0       441.0
# 1      191.0        65.0

# %%
df_info = df_info.drop(columns=['Hero|Publisher', 'Measurements'])
df_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height (cm) Weight (kg)
# 0      Marvel Comics      203.0       441.0
# 1  Dark Horse Comics      191.0        65.0

# %%
df_info["Height (cm)"] = df_info[["Height (cm)"]].astype(float)

# %%
df_info["Height (cm)"].head()
# Out:
# 0    203.0
# 1    191.0
# 2    185.0
# 3    203.0
# 4    193.0
# Name: Height (cm), dtype: float64

# %%
df_info["Weight (kg)"].head()
# Out:
# 0      441.0
# 1       65.0
# 2       90.0
# 3      441.0
# 4      122.0
# Name: Weight (kg), dtype: object

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       463 non-null    object
#  1   Race         463 non-null    object
#  2   Alignment    463 non-null    object
#  3   Hair color   463 non-null    object
#  4   Eye color    463 non-null    object
#  5   Skin color   463 non-null    object
#  6   Hero         463 non-null    object
#  7   Publisher    463 non-null    object
#  8   Height (cm)  463 non-null    float64
#  9   Weight (kg)  463 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 36.3+ KB

# %%
df = pd.concat((df, df_info), axis = 1)
df.head(2)
# Out:
#   hero_names                                             Powers Gender  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed   Male
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...   Male
#
#             Race Alignment Hair color Eye color Skin color        Hero  \
# 0          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher  Height (cm) Weight (kg)
# 0      Marvel Comics        203.0      441.0
# 1  Dark Horse Comics        191.0       65.0

# %%
df["Hero Names"] = df["hero_names"]
df = df.drop(columns=["hero_names", "Hero"])
df.head(2)
# Out:
#                                               Powers Gender           Race  \
# 0         Agility,Super Strength,Stamina,Super Speed   Male          Human
# 1  Accelerated Healing,Durability,Longevity,Super...   Male  Icthyo Sapien
#
#   Alignment Hair color Eye color Skin color          Publisher  Height (cm)  \
# 0      good    No Hair    yellow    Unknown      Marvel Comics        203.0
# 1      good    No Hair      blue       blue  Dark Horse Comics        191.0
#
#   Weight (kg) Hero Names
# 0      441.0     3-D Man
# 1       65.0      A-Bomb

# %%
## showing the lists are really strings
df.loc[0,'Powers']
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
## adding expand=True
# Create a new column where they were converted back to lists
df['Powers'].str.split(',', expand = True)
# Out:
#                       0                    1                2   \
# 0                Agility       Super Strength          Stamina
# 1    Accelerated Healing           Durability        Longevity
# 2                Agility  Accelerated Healing  Cold Resistance
# 3     Lantern Power Ring                 None             None
# 4    Accelerated Healing         Intelligence   Super Strength
# ..                   ...                  ...              ...
# 662               Flight        Energy Blasts    Size Changing
# 663      Cold Resistance           Durability        Longevity
# 664              Agility              Stealth     Danger Sense
# 665          Cryokinesis            Telepathy            Magic
# 666          Super Speed        Intangibility      Time Travel
#
#                     3                         4                5   \
# 0          Super Speed                      None             None
# 1       Super Strength                   Stamina       Camouflage
# ...

# %%
df["powers_split"] = df["Powers"].str.replace("","" , '"')
df["powers_split"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 df["powers_split"] = df["Powers"].str.replace("","" , '"')
#       2 df["powers_split"].value_counts()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\strings\accessor.py:129, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     124     msg = (
#     125         f"Cannot use .str.{func_name} with values of "
#     126         f"inferred dtype '{self._inferred_dtype}'."
#     127     )
#     128     raise TypeError(msg)
# --> 129 return func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\strings\accessor.py:1500, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1497 if case is None:
#    1498     case = True
# -> 1500 result = self._data.array._str_replace(
# ...

# %%
## Apply the json.loads to the full column
df["powers_split"] = df["powers_split"].apply(json.loads("s"))
df["powers_split"].head()

# %%
# Apply json.loads to entire column
df['powers_split'] = df['powers_split'].apply(json.loads("s"))
# check results
df['powers_split'].head()

# %%
df['Powers_split'].value_counts()

# %%
# Apply json.loads to entire column
df['Powers_split'] = df['Powers_split'].apply(json.loads)
# check results
df['Powers_split'].head()

# %%
## exploding the column of lists
exploded = df.explode("Powers_split")
exploded[["Powers","Powers_split"]].head(5)
